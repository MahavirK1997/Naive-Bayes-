# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_blobs
from scipy.stats import norm

# %%
X, y = make_blobs(n_samples=1000, n_features=2, centers=2, random_state=1)

# %%
print(X[:5])
print(y[:5])
# Out:
# [[ -3.05837272   4.48825769]
#  [ -8.60973869  -3.72714879]
#  [  1.37129721   5.23107449]
#  [ -9.33917563  -2.9544469 ]
#  [-11.57178593  -3.85275513]]
# [0 1 0 1 1]

# %%
class GaussianNaiveBayes:
  def __init__(self, X, y):
    self.X = X
    self.y = y

  def splitData(self):
    X_train, X_test, y_train, y_test = train_test_split(self.X, self.y,
                                                        test_size = 0.3,
                                                        random_state =1)
    return X_train, X_test, y_train, y_test

  def distribution(self, data):
    mean = np.mean(data)
    std = np.std(data)
    dist = norm(mean, std)
    return dist

  def probability(self, x, prior, dist1, dist2):
    return prior * dist1.pdf(x[0]) * dist2.pdf(x[1])

  def fit(self):
    self.X_train, self.X_test, self.y_train, self.y_test = self.splitData()
    # seperate data by class
    X0_train = self.X_train[self.y_train == 0]
    X1_train = self.X_train[self.y_train == 1]

    self.prior0 = len(X0_train)/len(self.X_train)
    self.prior1 = len(X1_train)/len(self.X_train)

    self.dist_X00 = self.distribution(X0_train[0]) # Dim 0 class 0
    self.dist_X10 = self.distribution(X0_train[1]) # Dim 1 class 0

    self.dist_X01 = self.distribution(X1_train[0]) # Dim 0 class 1
    self.dist_X11 = self.distribution(X1_train[1]) # Dim 1 class 1

  def predict(self):
    for sample, target in zip(self.X_test, self.y_test):  # iterate over 2 list with same indices
      py0 = self.probability(sample, self.prior0, self.dist_X00, self.dist_X10)
      py1 = self.probability(sample, self.prior1, self.dist_X01, self.dist_X11)

      print("P(y=0|%s) = %.3f" % (sample, py0 * 100))
      print("P(y=1|%s) = %.3f" % (sample, py1 * 100))
      print("The model predicted class {} and the actual class is {}".
            format(np.argmax([py0, py1]), target))

# %%
clf = GaussianNaiveBayes(X, y)

# %%
clf.fit()

# %%
clf.predict()
# Out:
# P(y=0|[0.03424921 4.60335965]) = 0.596
# P(y=1|[0.03424921 4.60335965]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-1.93540597  5.63544545]) = 0.324
# P(y=1|[-1.93540597  5.63544545]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-1.53940095  5.02369298]) = 0.441
# P(y=1|[-1.53940095  5.02369298]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-9.57470929 -4.08759711]) = 0.001
# P(y=1|[-9.57470929 -4.08759711]) = 0.244
# The model predicted class 1 and the actual class is 1
# P(y=0|[-10.57107323  -4.07059622]) = 0.000
# P(y=1|[-10.57107323  -4.07059622]) = 0.151
# The model predicted class 1 and the actual class is 1
# P(y=0|[0.8687658  4.15785509]) = 0.679
# P(y=1|[0.8687658  4.15785509]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-2.18191637  4.03723397]) = 0.511
# P(y=1|[-2.18191637  4.03723397]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-8.36577665 -4.35513738]) = 0.001
# P(y=1|[-8.36577665 -4.35513738]) = 0.400
# The model predicted class 1 and the actual class is 1
# P(y=0|[-10.63211721  -4.47845194]) = 0.000
# P(y=1|[-10.63211721  -4.47845194]) = 0.163
# The model predicted class 1 and the actual class is 1
# P(y=0|[-9.63436459 -4.93306874]) = 0.000
# P(y=1|[-9.63436459 -4.93306874]) = 0.293
# The model predicted class 1 and the actual class is 1
# P(y=0|[-1.03619773  3.97153319]) = 0.629
# P(y=1|[-1.03619773  3.97153319]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-8.46846464 -3.26686591]) = 0.003
# P(y=1|[-8.46846464 -3.26686591]) = 0.277
# The model predicted class 1 and the actual class is 1
# P(y=0|[-11.11268001  -5.25530757]) = 0.000
# P(y=1|[-11.11268001  -5.25530757]) = 0.147
# The model predicted class 1 and the actual class is 1
# P(y=0|[-10.44705835  -2.86809723]) = 0.001
# P(y=1|[-10.44705835  -2.86809723]) = 0.107
# The model predicted class 1 and the actual class is 1
# P(y=0|[-9.06942229 -3.86995971]) = 0.001
# P(y=1|[-9.06942229 -3.86995971]) = 0.278
# The model predicted class 1 and the actual class is 1
# P(y=0|[-0.50696077  4.1822541 ]) = 0.638
# P(y=1|[-0.50696077  4.1822541 ]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-3.73636193  5.35399104]) = 0.228
# P(y=1|[-3.73636193  5.35399104]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-10.44518578  -3.76476563]) = 0.000
# P(y=1|[-10.44518578  -3.76476563]) = 0.147
# The model predicted class 1 and the actual class is 1
# P(y=0|[-10.37740146  -4.32438007]) = 0.000
# P(y=1|[-10.37740146  -4.32438007]) = 0.179
# The model predicted class 1 and the actual class is 1
# P(y=0|[-1.26577217  4.17834918]) = 0.584
# P(y=1|[-1.26577217  4.17834918]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-1.85912062  3.7518867 ]) = 0.574
# P(y=1|[-1.85912062  3.7518867 ]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-10.85753953  -4.39125676]) = 0.000
# P(y=1|[-10.85753953  -4.39125676]) = 0.141
# The model predicted class 1 and the actual class is 1
# P(y=0|[-9.13970105 -5.31214539]) = 0.000
# P(y=1|[-9.13970105 -5.31214539]) = 0.382
# The model predicted class 1 and the actual class is 1
# P(y=0|[-1.79553723  3.60922008]) = 0.593
# P(y=1|[-1.79553723  3.60922008]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-1.59880971  4.61761462]) = 0.495
# P(y=1|[-1.59880971  4.61761462]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-10.07376347  -4.28021463]) = 0.000
# P(y=1|[-10.07376347  -4.28021463]) = 0.206
# The model predicted class 1 and the actual class is 1
# P(y=0|[-9.78647884 -1.90569371]) = 0.003
# P(y=1|[-9.78647884 -1.90569371]) = 0.095
# The model predicted class 1 and the actual class is 1
# P(y=0|[-10.74335655  -3.90529784]) = 0.000
# P(y=1|[-10.74335655  -3.90529784]) = 0.131
# The model predicted class 1 and the actual class is 1
# P(y=0|[-0.91900345  3.45278927]) = 0.692
# P(y=1|[-0.91900345  3.45278927]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-0.80627868  3.99346056]) = 0.644
# P(y=1|[-0.80627868  3.99346056]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-1.21819546  4.30633464]) = 0.571
# P(y=1|[-1.21819546  4.30633464]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-1.9764611   5.04747574]) = 0.404
# P(y=1|[-1.9764611   5.04747574]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-2.16853218  4.24000391]) = 0.490
# P(y=1|[-2.16853218  4.24000391]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-7.82544199 -4.77900244]) = 0.001
# P(y=1|[-7.82544199 -4.77900244]) = 0.508
# The model predicted class 1 and the actual class is 1
# P(y=0|[-11.32145791  -3.73701559]) = 0.000
# P(y=1|[-11.32145791  -3.73701559]) = 0.089
# The model predicted class 1 and the actual class is 1
# P(y=0|[-7.95804024 -2.35657665]) = 0.009
# P(y=1|[-7.95804024 -2.35657665]) = 0.219
# The model predicted class 1 and the actual class is 1
# P(y=0|[-1.15637509  5.69971575]) = 0.358
# P(y=1|[-1.15637509  5.69971575]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-11.14743529  -3.52772597]) = 0.000
# P(y=1|[-11.14743529  -3.52772597]) = 0.092
# The model predicted class 1 and the actual class is 1
# P(y=0|[-0.7885901   3.89803273]) = 0.657
# P(y=1|[-0.7885901   3.89803273]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-1.78245013  3.47072043]) = 0.606
# P(y=1|[-1.78245013  3.47072043]) = 0.002
# The model predicted class 0 and the actual class is 0
# P(y=0|[-9.35033739 -2.56652295]) = 0.003
# P(y=1|[-9.35033739 -2.56652295]) = 0.155
# The model predicted class 1 and the actual class is 1
# P(y=0|[-2.99151157  2.64580131]) = 0.485
# P(y=1|[-2.99151157  2.64580131]) = 0.006
# The model predicted class 0 and the actual class is 0
# P(y=0|[-10.35490003  -4.47472493]) = 0.000
# P(y=1|[-10.35490003  -4.47472493]) = 0.189
# The model predicted class 1 and the actual class is 1
# P(y=0|[-11.02151182  -3.38558381]) = 0.000
# P(y=1|[-11.02151182  -3.38558381]) = 0.095
# The model predicted class 1 and the actual class is 1
# P(y=0|[-8.39338856 -4.21983911]) = 0.001
# P(y=1|[-8.39338856 -4.21983911]) = 0.383
# The model predicted class 1 and the actual class is 1
# P(y=0|[-2.15068504  4.54086298]) = 0.456
# P(y=1|[-2.15068504  4.54086298]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-9.90159836 -3.80129621]) = 0.001
# P(y=1|[-9.90159836 -3.80129621]) = 0.194
# The model predicted class 1 and the actual class is 1
# P(y=0|[-1.89750184  5.56177775]) = 0.337
# P(y=1|[-1.89750184  5.56177775]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-2.57535176  3.99923783]) = 0.471
# P(y=1|[-2.57535176  3.99923783]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-2.25522779  4.09736855]) = 0.496
# P(y=1|[-2.25522779  4.09736855]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-3.61166519  3.00416072]) = 0.400
# P(y=1|[-3.61166519  3.00416072]) = 0.005
# The model predicted class 0 and the actual class is 0
# P(y=0|[-1.99084308  4.79302901]) = 0.438
# P(y=1|[-1.99084308  4.79302901]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-9.18211214 -4.23535445]) = 0.001
# P(y=1|[-9.18211214 -4.23535445]) = 0.297
# The model predicted class 1 and the actual class is 1
# P(y=0|[-0.56056357  3.50485538]) = 0.715
# P(y=1|[-0.56056357  3.50485538]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-9.60979139 -2.48386084]) = 0.003
# P(y=1|[-9.60979139 -2.48386084]) = 0.134
# The model predicted class 1 and the actual class is 1
# P(y=0|[-9.85883363 -5.1574499 ]) = 0.000
# P(y=1|[-9.85883363 -5.1574499 ]) = 0.277
# The model predicted class 1 and the actual class is 1
# P(y=0|[-10.79333912  -4.6634011 ]) = 0.000
# P(y=1|[-10.79333912  -4.6634011 ]) = 0.156
# The model predicted class 1 and the actual class is 1
# P(y=0|[-9.4769003  -3.89497666]) = 0.001
# P(y=1|[-9.4769003  -3.89497666]) = 0.240
# The model predicted class 1 and the actual class is 1
# P(y=0|[-0.8821407  4.2877187]) = 0.599
# P(y=1|[-0.8821407  4.2877187]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-1.26167948  3.41047898]) = 0.664
# P(y=1|[-1.26167948  3.41047898]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-1.47852116  5.51366532]) = 0.370
# P(y=1|[-1.47852116  5.51366532]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-0.72441213  6.21901768]) = 0.295
# P(y=1|[-0.72441213  6.21901768]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-7.88896407 -2.339787  ]) = 0.009
# P(y=1|[-7.88896407 -2.339787  ]) = 0.221
# The model predicted class 1 and the actual class is 1
# P(y=0|[-1.30901393  3.09420646]) = 0.679
# P(y=1|[-1.30901393  3.09420646]) = 0.002
# The model predicted class 0 and the actual class is 0
# P(y=0|[-11.40692178  -2.82262319]) = 0.000
# P(y=1|[-11.40692178  -2.82262319]) = 0.061
# The model predicted class 1 and the actual class is 1
# P(y=0|[-4.45264491  6.34401868]) = 0.112
# P(y=1|[-4.45264491  6.34401868]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-9.89732078 -3.63202271]) = 0.001
# P(y=1|[-9.89732078 -3.63202271]) = 0.184
# The model predicted class 1 and the actual class is 1
# P(y=0|[-8.12540924 -3.18553042]) = 0.004
# P(y=1|[-8.12540924 -3.18553042]) = 0.295
# The model predicted class 1 and the actual class is 1
# P(y=0|[-1.22357371  3.71900248]) = 0.641
# P(y=1|[-1.22357371  3.71900248]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-0.49811992  4.37896048]) = 0.610
# P(y=1|[-0.49811992  4.37896048]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-1.20794396  5.5106642 ]) = 0.386
# P(y=1|[-1.20794396  5.5106642 ]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-9.43679445 -4.8750076 ]) = 0.000
# P(y=1|[-9.43679445 -4.8750076 ]) = 0.314
# The model predicted class 1 and the actual class is 1
# P(y=0|[-10.81325985  -4.68327516]) = 0.000
# P(y=1|[-10.81325985  -4.68327516]) = 0.155
# The model predicted class 1 and the actual class is 1
# P(y=0|[-1.30568948  4.21953485]) = 0.575
# P(y=1|[-1.30568948  4.21953485]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-9.46976195 -5.51446844]) = 0.000
# P(y=1|[-9.46976195 -5.51446844]) = 0.347
# The model predicted class 1 and the actual class is 1
# P(y=0|[-0.85769887  4.45305717]) = 0.576
# P(y=1|[-0.85769887  4.45305717]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-9.96509702 -5.23098488]) = 0.000
# P(y=1|[-9.96509702 -5.23098488]) = 0.267
# The model predicted class 1 and the actual class is 1
# P(y=0|[-9.9439301  -4.41293038]) = 0.000
# P(y=1|[-9.9439301  -4.41293038]) = 0.226
# The model predicted class 1 and the actual class is 1
# P(y=0|[-8.3587509  -5.27883981]) = 0.000
# P(y=1|[-8.3587509  -5.27883981]) = 0.490
# The model predicted class 1 and the actual class is 1
# P(y=0|[-10.92939407  -5.02105089]) = 0.000
# P(y=1|[-10.92939407  -5.02105089]) = 0.156
# The model predicted class 1 and the actual class is 1
# P(y=0|[-11.31191354  -4.19515041]) = 0.000
# P(y=1|[-11.31191354  -4.19515041]) = 0.103
# The model predicted class 1 and the actual class is 1
# P(y=0|[-1.23363973  4.45557027]) = 0.548
# P(y=1|[-1.23363973  4.45557027]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-0.80627772  4.26677814]) = 0.607
# P(y=1|[-0.80627772  4.26677814]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-1.3748118   4.66895731]) = 0.506
# P(y=1|[-1.3748118   4.66895731]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-8.50581514 -3.92333702]) = 0.002
# P(y=1|[-8.50581514 -3.92333702]) = 0.341
# The model predicted class 1 and the actual class is 1
# P(y=0|[-11.19886816  -4.25244351]) = 0.000
# P(y=1|[-11.19886816  -4.25244351]) = 0.112
# The model predicted class 1 and the actual class is 1
# P(y=0|[-9.87039787 -4.02429822]) = 0.001
# P(y=1|[-9.87039787 -4.02429822]) = 0.210
# The model predicted class 1 and the actual class is 1
# P(y=0|[-8.95767405 -3.3800831 ]) = 0.002
# P(y=1|[-8.95767405 -3.3800831 ]) = 0.246
# The model predicted class 1 and the actual class is 1
# P(y=0|[-10.3707327   -5.28565384]) = 0.000
# P(y=1|[-10.3707327   -5.28565384]) = 0.222
# The model predicted class 1 and the actual class is 1
# P(y=0|[-9.78935958 -4.68169863]) = 0.000
# P(y=1|[-9.78935958 -4.68169863]) = 0.259
# The model predicted class 1 and the actual class is 1
# P(y=0|[-0.04261031  4.90923075]) = 0.541
# P(y=1|[-0.04261031  4.90923075]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-1.22139356  5.52881819]) = 0.382
# P(y=1|[-1.22139356  5.52881819]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-10.35522672  -3.43069337]) = 0.001
# P(y=1|[-10.35522672  -3.43069337]) = 0.138
# The model predicted class 1 and the actual class is 1
# P(y=0|[-2.43526791e-03  5.82416388e+00]) = 0.379
# P(y=1|[-2.43526791e-03  5.82416388e+00]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-1.96967668  1.9716521 ]) = 0.597
# P(y=1|[-1.96967668  1.9716521 ]) = 0.007
# The model predicted class 0 and the actual class is 0
# P(y=0|[-1.67701486  5.13789239]) = 0.413
# P(y=1|[-1.67701486  5.13789239]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-9.92283641 -5.74028395]) = 0.000
# P(y=1|[-9.92283641 -5.74028395]) = 0.295
# The model predicted class 1 and the actual class is 1
# P(y=0|[-3.4474728   4.76833718]) = 0.306
# P(y=1|[-3.4474728   4.76833718]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-1.32233897  5.4145553 ]) = 0.394
# P(y=1|[-1.32233897  5.4145553 ]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[1.66151885 3.80626454]) = 0.707
# P(y=1|[1.66151885 3.80626454]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-10.74523877  -4.54002899]) = 0.000
# P(y=1|[-10.74523877  -4.54002899]) = 0.156
# The model predicted class 1 and the actual class is 1
# P(y=0|[-1.0749133   4.73076411]) = 0.519
# P(y=1|[-1.0749133   4.73076411]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-1.05315596  6.70020748]) = 0.218
# P(y=1|[-1.05315596  6.70020748]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-1.37148174  5.90459805]) = 0.316
# P(y=1|[-1.37148174  5.90459805]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-0.55094315  3.70356947]) = 0.696
# P(y=1|[-0.55094315  3.70356947]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-10.69936104  -4.36071823]) = 0.000
# P(y=1|[-10.69936104  -4.36071823]) = 0.153
# The model predicted class 1 and the actual class is 1
# P(y=0|[-10.6955224   -4.53167426]) = 0.000
# P(y=1|[-10.6955224   -4.53167426]) = 0.160
# The model predicted class 1 and the actual class is 1
# P(y=0|[-1.19291664  5.44017674]) = 0.398
# P(y=1|[-1.19291664  5.44017674]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-0.38580398  6.37359162]) = 0.281
# P(y=1|[-0.38580398  6.37359162]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-8.40324787 -4.84879007]) = 0.001
# P(y=1|[-8.40324787 -4.84879007]) = 0.445
# The model predicted class 1 and the actual class is 1
# P(y=0|[-0.87433299  3.7416221 ]) = 0.668
# P(y=1|[-0.87433299  3.7416221 ]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-1.53118292  6.16690505]) = 0.272
# P(y=1|[-1.53118292  6.16690505]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-9.43890952 -5.45823983]) = 0.000
# P(y=1|[-9.43890952 -5.45823983]) = 0.349
# The model predicted class 1 and the actual class is 1
# P(y=0|[-1.98197711  4.02243551]) = 0.533
# P(y=1|[-1.98197711  4.02243551]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-10.18360468  -3.40392672]) = 0.001
# P(y=1|[-10.18360468  -3.40392672]) = 0.149
# The model predicted class 1 and the actual class is 1
# P(y=0|[-1.26513188  5.13201243]) = 0.443
# P(y=1|[-1.26513188  5.13201243]) = 0.000
# The model predicted class 0 and the actual class is 0
# P(y=0|[-9.34978769 -5.30499793]) = 0.000
# P(y=1|[-9.34978769 -5.30499793]) = 0.352
# The model predicted class 1 and the actual class is 1
# P(y=0|[-2.70509415  4.76177438]) = 0.376
# P(y=1|[-2.70509415  4.76177438]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-9.10179102 -5.06012742]) = 0.000
# P(y=1|[-9.10179102 -5.06012742]) = 0.370
# The model predicted class 1 and the actual class is 1
# P(y=0|[-10.41378805  -3.32169145]) = 0.001
# P(y=1|[-10.41378805  -3.32169145]) = 0.129
# The model predicted class 1 and the actual class is 1
# P(y=0|[-2.51705673  3.47230803]) = 0.519
# P(y=1|[-2.51705673  3.47230803]) = 0.002
# The model predicted class 0 and the actual class is 0
# P(y=0|[-0.81339926  3.54697393]) = 0.692
# P(y=1|[-0.81339926  3.54697393]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-9.33917563 -2.9544469 ]) = 0.002
# P(y=1|[-9.33917563 -2.9544469 ]) = 0.183
# The model predicted class 1 and the actual class is 1
# P(y=0|[-2.93002068  4.6894854 ]) = 0.363
# P(y=1|[-2.93002068  4.6894854 ]) = 0.001
# The model predicted class 0 and the actual class is 0
# P(y=0|[-10.2646428   -3.24419138]) = 0.001
# P(y=1|[-10.2646428   -3.24419138]) = 0.135
# The model predicted class 1 and the actual class is 1
# P(y=0|[-2.22334864  4.49617628]) = 0.454
# P(y=1|[-2.22334864  4.49617628]) = 0.001
# The model predicted class 0 and the actual class is 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-5f00151abcfc> in <module>()
# ----> 1 clf.predict()
#
# <ipython-input-17-9b51c0936678> in predict(self)
#      42       print("P(y=1|%s) = %.3f" % (sample, py1 * 100))
#      43       print("The model predicted class {} and the actual class is {}".
# ---> 44             format(np.argmax([py0, py1]), target))
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
df = pd.read_excel("Dry_Bean_Dataset.xlsx")
df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# 0     0.913358      0.007332      0.003147      0.834222      0.998724  SEKER
# 1     0.953861      0.006979      0.003564      0.909851      0.998430  SEKER
# 2     0.908774      0.007244      0.003048      0.825871      0.999066  SEKER
# 3     0.928329      0.007017      0.003215      0.861794      0.994199  SEKER
# 4     0.970516      0.006697      0.003665      0.941900      0.999166  SEKER

# %%
df.corr()
# Out:
#                      Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# Area             1.000000   0.966722         0.931834         0.951602
# Perimeter        0.966722   1.000000         0.977338         0.913179
# MajorAxisLength  0.931834   0.977338         1.000000         0.826052
# MinorAxisLength  0.951602   0.913179         0.826052         1.000000
# AspectRation     0.241735   0.385276         0.550335        -0.009161
# Eccentricity     0.267481   0.391066         0.541972         0.019574
# ConvexArea       0.999939   0.967689         0.932607         0.951339
# EquivDiameter    0.984968   0.991380         0.961733         0.948539
# Extent           0.054345  -0.021160        -0.078062         0.145957
# Solidity        -0.196585  -0.303970        -0.284302        -0.155831
# roundness       -0.357530  -0.547647        -0.596358        -0.210344
# Compactness     -0.268067  -0.406857        -0.568377        -0.015066
# ShapeFactor1    -0.847958  -0.864623        -0.773609        -0.947204
# ShapeFactor2    -0.639291  -0.767592        -0.859238        -0.471347
# ShapeFactor3    -0.272145  -0.408435        -0.568185        -0.019326
# ShapeFactor4    -0.355721  -0.429310        -0.482527        -0.263749
#
#                  AspectRation  Eccentricity  ConvexArea  EquivDiameter  \
# Area                 0.241735      0.267481    0.999939       0.984968
# Perimeter            0.385276      0.391066    0.967689       0.991380
# MajorAxisLength      0.550335      0.541972    0.932607       0.961733
# MinorAxisLength     -0.009161      0.019574    0.951339       0.948539
# AspectRation         1.000000      0.924293    0.243301       0.303647
# Eccentricity         0.924293      1.000000    0.269255       0.318667
# ConvexArea           0.243301      0.269255    1.000000       0.985226
# EquivDiameter        0.303647      0.318667    0.985226       1.000000
# Extent              -0.370184     -0.319362    0.052564       0.028383
# Solidity            -0.267754     -0.297592   -0.206191      -0.231648
# roundness           -0.766979     -0.722272   -0.362083      -0.435945
# Compactness         -0.987687     -0.970313   -0.269922      -0.327650
# ShapeFactor1         0.024593      0.019920   -0.847950      -0.892741
# ShapeFactor2        -0.837841     -0.860141   -0.640862      -0.713069
# ShapeFactor3        -0.978592     -0.981058   -0.274024      -0.330389
# ShapeFactor4        -0.449264     -0.449354   -0.362049      -0.392512
#
#                    Extent  Solidity  roundness  Compactness  ShapeFactor1  \
# Area             0.054345 -0.196585  -0.357530    -0.268067     -0.847958
# Perimeter       -0.021160 -0.303970  -0.547647    -0.406857     -0.864623
# MajorAxisLength -0.078062 -0.284302  -0.596358    -0.568377     -0.773609
# MinorAxisLength  0.145957 -0.155831  -0.210344    -0.015066     -0.947204
# AspectRation    -0.370184 -0.267754  -0.766979    -0.987687      0.024593
# Eccentricity    -0.319362 -0.297592  -0.722272    -0.970313      0.019920
# ConvexArea       0.052564 -0.206191  -0.362083    -0.269922     -0.847950
# EquivDiameter    0.028383 -0.231648  -0.435945    -0.327650     -0.892741
# Extent           1.000000  0.191389   0.344411     0.354212     -0.141616
# Solidity         0.191389  1.000000   0.607150     0.303766      0.153388
# roundness        0.344411  0.607150   1.000000     0.768086      0.230273
# Compactness      0.354212  0.303766   0.768086     1.000000     -0.009394
# ShapeFactor1    -0.141616  0.153388   0.230273    -0.009394      1.000000
# ShapeFactor2     0.237956  0.343559   0.782824     0.868939      0.469197
# ShapeFactor3     0.347624  0.307662   0.763126     0.998686     -0.008320
# ShapeFactor4     0.148502  0.702163   0.472149     0.484436      0.248619
#
#                  ShapeFactor2  ShapeFactor3  ShapeFactor4
# Area                -0.639291     -0.272145     -0.355721
# Perimeter           -0.767592     -0.408435     -0.429310
# MajorAxisLength     -0.859238     -0.568185     -0.482527
# MinorAxisLength     -0.471347     -0.019326     -0.263749
# AspectRation        -0.837841     -0.978592     -0.449264
# Eccentricity        -0.860141     -0.981058     -0.449354
# ConvexArea          -0.640862     -0.274024     -0.362049
# EquivDiameter       -0.713069     -0.330389     -0.392512
# Extent               0.237956      0.347624      0.148502
# Solidity             0.343559      0.307662      0.702163
# roundness            0.782824      0.763126      0.472149
# Compactness          0.868939      0.998686      0.484436
# ShapeFactor1         0.469197     -0.008320      0.248619
# ShapeFactor2         1.000000      0.872971      0.529932
# ShapeFactor3         0.872971      1.000000      0.484274
# ShapeFactor4         0.529932      0.484274      1.000000

# %%
df = df.drop(columns = ['ConvexArea', 'EquivDiameter', 'ShapeFactor3', 'Perimeter', 'MinorAxisLength', 'AspectRation', 'MajorAxisLength'])

# %%
df
# Out:
#         Area  Eccentricity    Extent  Solidity  roundness  Compactness  \
# 0      28395      0.549812  0.763923  0.988856   0.958027     0.913358
# 1      28734      0.411785  0.783968  0.984986   0.887034     0.953861
# 2      29380      0.562727  0.778113  0.989559   0.947849     0.908774
# 3      30008      0.498616  0.782681  0.976696   0.903936     0.928329
# 4      30140      0.333680  0.773098  0.990893   0.984877     0.970516
# ...      ...           ...       ...       ...        ...          ...
# 13606  42097      0.765002  0.714574  0.990331   0.916603     0.801865
# 13607  42101      0.735702  0.799943  0.990752   0.922015     0.822252
# 13608  42139      0.734065  0.729932  0.989899   0.918424     0.822730
# 13609  42147      0.741055  0.705389  0.987813   0.907906     0.817457
# 13610  42159      0.786693  0.788962  0.989648   0.888380     0.784997
#
#        ShapeFactor1  ShapeFactor2  ShapeFactor4     Class
# 0          0.007332      0.003147      0.998724     SEKER
# 1          0.006979      0.003564      0.998430     SEKER
# 2          0.007244      0.003048      0.999066     SEKER
# 3          0.007017      0.003215      0.994199     SEKER
# 4          0.006697      0.003665      0.999166     SEKER
# ...             ...           ...           ...       ...
# 13606      0.006858      0.001749      0.998385  DERMASON
# 13607      0.006688      0.001886      0.998219  DERMASON
# 13608      0.006681      0.001888      0.996767  DERMASON
# 13609      0.006724      0.001852      0.995222  DERMASON
# 13610      0.007001      0.001640      0.998180  DERMASON
#
# [13611 rows x 10 columns]

# %%
df.corr()
# Out:
#                   Area  Eccentricity    Extent  Solidity  roundness  \
# Area          1.000000      0.267481  0.054345 -0.196585  -0.357530
# Eccentricity  0.267481      1.000000 -0.319362 -0.297592  -0.722272
# Extent        0.054345     -0.319362  1.000000  0.191389   0.344411
# Solidity     -0.196585     -0.297592  0.191389  1.000000   0.607150
# roundness    -0.357530     -0.722272  0.344411  0.607150   1.000000
# Compactness  -0.268067     -0.970313  0.354212  0.303766   0.768086
# ShapeFactor1 -0.847958      0.019920 -0.141616  0.153388   0.230273
# ShapeFactor2 -0.639291     -0.860141  0.237956  0.343559   0.782824
# ShapeFactor4 -0.355721     -0.449354  0.148502  0.702163   0.472149
#
#               Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor4
# Area            -0.268067     -0.847958     -0.639291     -0.355721
# Eccentricity    -0.970313      0.019920     -0.860141     -0.449354
# Extent           0.354212     -0.141616      0.237956      0.148502
# Solidity         0.303766      0.153388      0.343559      0.702163
# roundness        0.768086      0.230273      0.782824      0.472149
# Compactness      1.000000     -0.009394      0.868939      0.484436
# ShapeFactor1    -0.009394      1.000000      0.469197      0.248619
# ShapeFactor2     0.868939      0.469197      1.000000      0.529932
# ShapeFactor4     0.484436      0.248619      0.529932      1.000000

# %%
def centralize(X):
    return (X - X.mean)

# %%
X = df.iloc[:,:-1]
X
# Out:
#         Area  Eccentricity    Extent  Solidity  roundness  Compactness  \
# 0      28395      0.549812  0.763923  0.988856   0.958027     0.913358
# 1      28734      0.411785  0.783968  0.984986   0.887034     0.953861
# 2      29380      0.562727  0.778113  0.989559   0.947849     0.908774
# 3      30008      0.498616  0.782681  0.976696   0.903936     0.928329
# 4      30140      0.333680  0.773098  0.990893   0.984877     0.970516
# ...      ...           ...       ...       ...        ...          ...
# 13606  42097      0.765002  0.714574  0.990331   0.916603     0.801865
# 13607  42101      0.735702  0.799943  0.990752   0.922015     0.822252
# 13608  42139      0.734065  0.729932  0.989899   0.918424     0.822730
# 13609  42147      0.741055  0.705389  0.987813   0.907906     0.817457
# 13610  42159      0.786693  0.788962  0.989648   0.888380     0.784997
#
#        ShapeFactor1  ShapeFactor2  ShapeFactor4
# 0          0.007332      0.003147      0.998724
# 1          0.006979      0.003564      0.998430
# 2          0.007244      0.003048      0.999066
# 3          0.007017      0.003215      0.994199
# 4          0.006697      0.003665      0.999166
# ...             ...           ...           ...
# 13606      0.006858      0.001749      0.998385
# 13607      0.006688      0.001886      0.998219
# 13608      0.006681      0.001888      0.996767
# 13609      0.006724      0.001852      0.995222
# 13610      0.007001      0.001640      0.998180
#
# [13611 rows x 9 columns]

# %%
t = np.mean(X.values, axis = 1)

# %%
def distribution(data):
    mean = np.mean(data)
    std = np.std(data)
    dist = norm(mean, std)
    return dist

# %%
distribution(X.values)
